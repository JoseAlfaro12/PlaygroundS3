# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('../Data/train.csv')
test = pd.read_csv('../Data/test.csv')

# %%
display(train.head())
display(train.shape)
display(train.columns)
display(train.dtypes)
display(train.describe())
# Out:
#    id  X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0   0        584        590     909972     909977            16            8
# 1   1        808        816     728350     728372           433           20
# 2   2         39        192    2212076    2212144         11388          705
# 3   3        781        789    3353146    3353173           210           16
# 4   4       1540       1560     618457     618502           521           72
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  ...  \
# 0            5               2274                    113  ...
# 1           54              44478                     70  ...
# 2          420            1311391                     29  ...
# 3           29               3202                    114  ...
# 4           67              48231                     82  ...
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas  Pastry  Z_Scratch  \
# ...

# %%
display(test.head())
display(test.shape)
display(test.columns)
display(test.dtypes)
display(test.describe())
# Out:
#       id  X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  \
# 0  19219       1015       1033    3826564    3826588           659
# 1  19220       1257       1271     419960     419973           370
# 2  19221       1358       1372     117715     117724           289
# 3  19222        158        168     232415     232440            80
# 4  19223        559        592     544375     544389           140
#
#    X_Perimeter  Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  ...  \
# 0           23           46              62357                     67  ...
# 1           26           28              39293                     92  ...
# 2           36           32              29386                    101  ...
# 3           10           11               8586                    107  ...
# 4           19           15              15524                    103  ...
#
#    Outside_X_Index  Edges_X_Index  Edges_Y_Index  Outside_Global_Index  \
# ...

# %% [markdown]
# ### Compare the Distributions Between Training and Testing Datasets

# %%
# List of numeric columns
numeric_columns = test.select_dtypes(include='number').columns

# Loop through each numeric column
for column in numeric_columns:
    # Create separate histograms for train and test datasets
    plt.figure(figsize=(12, 6))
    sns.histplot(train[column], bins=50, kde=True, color='blue', label='Train')
    sns.histplot(test[column], bins=50, kde=True, color='orange', label='Test')
    plt.title(f'Distribution of {column} in Train and Test datasets')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()
